# %%
import pandas as pd
import numpy as np
import yfinance as yf

print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("yfinance:", yf.__version__)
# Out:
# pandas: 3.0.5
# numpy: 2.5.2
# yfinance: 1.7.0

# %%
ticker = "^GSPC"

sp500 = yf.download(
    ticker,
    start="2015-01-01",
    end="2026-09-01",
    auto_adjust=False
)

sp500.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price         Adj Close        Close         High          Low         Open  \
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC        ^GSPC
# Date
# 2015-01-02  2058.199951  2058.199951  2072.360107  2046.040039  2058.899902
# 2015-01-05  2020.579956  2020.579956  2054.439941  2017.339966  2054.439941
# 2015-01-06  2002.609985  2002.609985  2030.250000  1992.439941  2022.150024
# 2015-01-07  2025.900024  2025.900024  2029.609985  2005.550049  2005.550049
# 2015-01-08  2062.139893  2062.139893  2064.080078  2030.609985  2030.609985
#
# Price           Volume
# Ticker           ^GSPC
# Date
# 2015-01-02  2708700000
# 2015-01-05  3799120000
# 2015-01-06  4460110000
# 2015-01-07  3805480000
# 2015-01-08  3934010000

# %%
print("Размер данных:", sp500.shape)
print("Дата начала:", sp500.index.min())
print("Дата окончания:", sp500.index.max())
# Out:
# Размер данных: (2932, 6)
# Дата начала: 2015-01-02 00:00:00
# Дата окончания: 2026-08-31 00:00:00

# %%
sp500.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 2932 entries, 2015-01-02 to 2026-08-31
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Adj Close, ^GSPC)  2932 non-null   float64
#  1   (Close, ^GSPC)      2932 non-null   float64
#  2   (High, ^GSPC)       2932 non-null   float64
#  3   (Low, ^GSPC)        2932 non-null   float64
#  4   (Open, ^GSPC)       2932 non-null   float64
#  5   (Volume, ^GSPC)     2932 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 160.3 KB

# %%
sp500.isna().sum()
# Out:
# Price      Ticker
# Adj Close  ^GSPC     0
# Close      ^GSPC     0
# High       ^GSPC     0
# Low        ^GSPC     0
# Open       ^GSPC     0
# Volume     ^GSPC     0
# dtype: int64

# %%
print(sp500.columns)
print()
print("Тип колонок:", type(sp500.columns))
print("Количество уровней:", sp500.columns.nlevels)
# Out:
# MultiIndex([('Adj Close', '^GSPC'),
#             (    'Close', '^GSPC'),
#             (     'High', '^GSPC'),
#             (      'Low', '^GSPC'),
#             (     'Open', '^GSPC'),
#             (   'Volume', '^GSPC')],
#            names=['Price', 'Ticker'])
#
# Тип колонок: <class 'pandas.MultiIndex'>
# Количество уровней: 2

# %%
sp500.columns = sp500.columns.get_level_values(0)

print(sp500.columns)
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='str', name='Price')

# %%
print(sp500.shape)
print(sp500.index.min())
print(sp500.index.max())

print("\nПропуски:")
print(sp500.isna().sum())

print("\nТипы данных:")
print(sp500.dtypes)
# Out:
# (2932, 6)
# 2015-01-02 00:00:00
# 2026-08-31 00:00:00
#
# Пропуски:
# Price
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume       0
# dtype: int64
#
# Типы данных:
# Price
# Adj Close    float64
# Close        float64
# High         float64
# Low          float64
# Open         float64
# Volume         int64
# dtype: object

# %%
print(sp500["Close"].describe())
# Out:
# count    2932.000000
# mean     3817.024202
# std      1533.388123
# min      1829.079956
# 25%      2561.044983
# 50%      3494.489990
# 75%      4595.077393
# max      7798.990234
# Name: Close, dtype: float64

# %%
sp500.to_csv("../data/raw/sp500_index.csv")

print("Данные сохранены.")
# Out:
# Данные сохранены.
